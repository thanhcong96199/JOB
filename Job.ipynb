# %%
import requests
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
urls = 'https://careerbuilder.vn/viec-lam/cntt-phan-mem-tai-ha-noi-c1l4-vi.html'
req = requests.get(urls)
soup = BeautifulSoup(req.text, 'html.parser')

tag_h3 =  soup.find_all('h3',{'class': 'job'})
job_title = [tag_h3[i].text for i in range(0,len(tag_h3))]

tag_p_namecom = soup.find_all('p', {'class': 'namecom'})
job_company = [tag_p_namecom[i].text for i in range(0, len(tag_p_namecom))]

job_links = [tag_h3[i].a.get('href') for i in range(0,len(tag_h3))]

tag_p_location = soup.find_all('p',{'class': 'location'})
job_locations = [tag_p_location[i].text for i in range(0, len(tag_p))]



data = pd.DataFrame({'title': job_title, 'company': job_company, 'job_location': job_locations, 'link':job_links})
data
sns.countplot(y = job_locations, data = data)

# %%
job_salary
# Out:
# ['Lương: 11 Tr - 33 Tr VND',
#  'Lương: 2 Tr - 4 Tr VND',
#  'Lương: 10 Tr - 30 Tr VND',
#  'Lương: 600 - 1,500 USD',
#  'Lương: 12 Tr - 18 Tr VND',
#  'Lương: 10 Tr - 20 Tr VND',
#  'Lương: 1 Tr - 2 Tr VND',
#  'Lương: 10 Tr - 12 Tr VND',
#  'Lương: 3 Tr - 5 Tr VND',
#  'Lương: 13,2 Tr - 33 Tr VND',
#  'Lương: 30 Tr - 60 Tr VND',
#  'Lương: 13,2 Tr - 33 Tr VND',
#  'Lương: 22 Tr - 33 Tr VND',
#  'Lương: 44 Tr - 88 Tr VND',
#  'Lương: 15,4 Tr - 22 Tr VND',
#  'Lương: 33 Tr - 44 Tr VND',
#  'Lương: 22 Tr - 55 Tr VND',
#  'Lương: 13,2 Tr - 33 Tr VND',
#  'Lương: 13,2 Tr - 33 Tr VND',
#  'Lương: Dưới 33 Tr VND',
#  'Lương: 8 Tr - 12 Tr VND',
#  'Lương: 22 Tr - 66 Tr VND',
#  'Lương: 22 Tr - 33 Tr VND',
#  'Lương: 7 Tr - 10 Tr VND',
#  'Lương: 17,6 Tr - 26,4 Tr VND',
#  'Lương: 16,5 Tr - 27,5 Tr VND',
#  'Lương: 22 Tr - 33 Tr VND',
#  'Lương: 19,8 Tr - 24,2 Tr VND',
#  'Lương: 17,6 Tr - 33 Tr VND',
#  'Lương: 30 Tr - 60 Tr VND',
#  'Lương: 22 Tr - 44 Tr VND',
# ...

# %%
tag_p_salarylred
# Out:
# [<p class="salary lred"><i class="fa fa-dollar fa-fw"></i>Lương: 11 Tr - 33 Tr VND</p>,
#  <p class="salary lred"><i class="fa fa-dollar fa-fw"></i>Lương: 2 Tr - 4 Tr VND</p>,
#  <p class="salary lred"><i class="fa fa-dollar fa-fw"></i>Lương: 10 Tr - 30 Tr VND</p>,
#  <p class="salary lred"><i class="fa fa-dollar fa-fw"></i>Lương: 600 - 1,500 USD</p>,
#  <p class="salary lred"><i class="fa fa-dollar fa-fw"></i>Lương: 12 Tr - 18 Tr VND</p>,
#  <p class="salary lred"><i class="fa fa-dollar fa-fw"></i>Lương: 10 Tr - 20 Tr VND</p>,
#  <p class="salary lred"><i class="fa fa-dollar fa-fw"></i>Lương: 1 Tr - 2 Tr VND</p>,
#  <p class="salary lred"><i class="fa fa-dollar fa-fw"></i>Lương: 10 Tr - 12 Tr VND</p>,
#  <p class="salary lred"><i class="fa fa-dollar fa-fw"></i>Lương: 3 Tr - 5 Tr VND</p>,
#  <p class="salary lred"><i class="fa fa-dollar fa-fw"></i>Lương: 13,2 Tr - 33 Tr VND</p>,
#  <p class="salary lred"><i class="fa fa-dollar fa-fw"></i>Lương: 30 Tr - 60 Tr VND</p>,
# ...

# %%
job_salary

# %%
job_locations
# Out:
# ['Hồ Chí Minh, Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội, Hồ Chí Minh, Toàn quốc',
#  'Hà Nội',
#  'Hà Nội, Hồ Chí Minh',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Tokyo, Hà Nội, Yokohama',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hồ Chí Minh, Hà Nội, Cần Thơ',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội',
#  'Hà Nội, Tokyo, Osaka',
#  'Quốc tế, Hà Nội, Hồ Chí Minh',
#  'Hà Nội',
#  'Hà Nội']

# %%
job_company
# Out:
# ['Công Ty Cổ Phần Tư vấn Quản Trị Doanh Nghiệp Tinh Vân',
#  'Tổ Hợp Công Nghệ Giáo Dục Topica',
#  'Ngân Hàng TMCP Việt Nam Thịnh Vượng - VPBANK',
#  'Tổ Hợp Công Nghệ Giáo Dục Topica',
#  'Ngân Hàng TMCP Đầu Tư và Phát Triển Việt Nam',
#  'Giao hàng tiết kiệm',
#  ' Báo điện tử VnExpress.net',
#  'Công ty Cổ phần Base Enterprise',
#  'Công ty Cổ phần Base Enterprise',
#  'Công Ty TNHH FPT Trading',
#  'Tập đoàn Internet Novaon',
#  'LienVietPostBank',
#  'LienVietPostBank',
#  'LienVietPostBank',
#  'Công ty cổ phần An ninh an toàn thông tin CMC',
#  'Công ty Cổ Phần Viễn Thông FPT',
#  'Công Ty Cổ Phần Quốc Tế Sơn Hà',
#  'Công ty cổ phần An ninh an toàn thông tin CMC',
#  'Công ty cổ phần An ninh an toàn thông tin CMC',
#  'Công Ty CP Chứng Khoán VNDIRECT',
#  'Công ty CP Đầu Tư Hàng Tiêu Dùng Quốc Tế',
#  'LienVietPostBank',
#  'CÔNG TY TNHH GLOBE 3 ERP VIỆT NAM',
#  'CÔNG TY TNHH GLOBE 3 ERP VIỆT NAM',
#  'Công Ty Cổ phần Công nghệ Thành Công Á Châu - VietInterview',
# ...

# %%
tag_p_namecom
# Out:
# [<p class="namecom"><a href="https://careerbuilder.vn/vi/nha-tuyen-dung/cong-ty-co-phan-tu-van-quan-tri-doanh-nghiep-tinh-van.35A7A44C.html">Công Ty Cổ Phần Tư vấn Quản Trị Doanh Nghiệp Tinh Vân</a></p>,
#  <p class="namecom"><a href="https://careerbuilder.vn/vi/nha-tuyen-dung/to-hop-cong-nghe-giao-duc-topica.35A6590E.html">Tổ Hợp Công Nghệ Giáo Dục Topica</a></p>,
#  <p class="namecom"><a href="https://careerbuilder.vn/vi/nha-tuyen-dung/ngan-hang-tmcp-viet-nam-thinh-vuong-vpbank.35A6CA10.html">Ngân Hàng TMCP Việt Nam Thịnh Vượng - VPBANK</a></p>,
#  <p class="namecom"><a href="https://careerbuilder.vn/vi/nha-tuyen-dung/to-hop-cong-nghe-giao-duc-topica.35A6590E.html">Tổ Hợp Công Nghệ Giáo Dục Topica</a></p>,
#  <p class="namecom"><a href="https://careerbuilder.vn/vi/nha-tuyen-dung/ngan-hang-tmcp-dau-tu-va-phat-trien-viet-nam.35A7DEFE.html">Ngân Hàng TMCP Đầu Tư và Phát Triển Việt Nam</a></p>,
# ...

# %%
job_title
# Out:
# ['Lập Trình Viên .Net (Mới)',
#  'Chương trình tuyển dụng 20 Lập trình viên Fresher ',
#  'Strategy Officer - VPBank ',
#  'Senior Developper - Chuyên Gia Lập Trình ',
#  'Tuyển Dụng Tập Trung Cán Bộ Công Nghệ Thông Tin ',
#  'PHP Developer (600 – 1500)-không yêu cầu kinh nghiệm (Mới)',
#  'PHP Developer (Mới)',
#  'PHP Developer (Mới)',
#  '[Ha Noi] Sales Representative (Mới)',
#  '[Hà Nội] Nhân Viên IT Helpdesk (Mới)',
#  'THỰC TẬP SINH PHP (Mới)',
#  'HO - Khối CNTT - Chuyên Viên Ban Quản Lý Dự Án (Mới)',
#  'HO - Khối CNTT - Chuyên Viên Phân Tích Nghiệp Vụ (BA) (Mới)',
#  'HO - Khối CNTT - Chuyên Viên Phát Triển Ứng Dụng Thanh Toán & Tích Hợp (Mới)',
#  'Penetration Testing ',
#  'Chuyên Viên Phát Triển Hệ Thống Đào Tạo E - Learning ',
#  'Chuyên viên IT quản trị hệ thống (Gấp) ',
#  'Chuyên Viên Phân Tích Malware ',
#  'Chuyên Gia Tư Vấn Giải Pháp ',
#  'Chuyên viên vận hành hệ thống Core chứng khoán ',
#  'Thực Tập Sinh/CTV Lập Trình Phần Mềm ',
# ...

# %%
# Out:
# [<h3 class="job"><a href="https://careerbuilder.vn/vi/tim-viec-lam/lap-trinh-vien-net.35AEC410.html" target="_blank">Lập Trình Viên .Net</a> <em class="set_jobnew">(Mới)</em></h3>,
#  <h3 class="job"><a href="https://careerbuilder.vn/vi/tim-viec-lam/chuong-trinh-tuyen-dung-20-lap-trinh-vien-fresher.35AE8425.html" target="_blank">Chương trình tuyển dụng 20 Lập trình viên Fresher</a> </h3>,
#  <h3 class="job"><a href="https://careerbuilder.vn/vi/tim-viec-lam/strategy-officer-vpbank.35AE0F26.html" target="_blank">Strategy Officer - VPBank</a> </h3>,
#  <h3 class="job"><a href="https://careerbuilder.vn/vi/tim-viec-lam/senior-developper-chuyen-gia-lap-trinh.35AE6B6C.html" target="_blank">Senior Developper - Chuyên Gia Lập Trình</a> </h3>,
#  <h3 class="job"><a href="https://careerbuilder.vn/vi/tim-viec-lam/tuyen-dung-tap-trung-can-bo-cong-nghe-thong-tin.35AE9F5A.html" target="_blank">Tuyển Dụng Tập Trung Cán Bộ Công Nghệ Thông Tin</a> </h3>,
# ...

# %%
req = requests.get(urls)

# %%
req
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(req.text, 'html.parser')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-5feb7ca47499> in <module>()
# ----> 1 job_title = [tag_h3[i].a.text for i in range(0,len(tag_h3))]
#
# NameError: name 'tag_h3' is not defined

# %%
tag_h3 =  soup.find_all('h3',{'class': 'job'})

# %%
tag_h3
# Out:
# [<h3 class="job"><a href="https://careerbuilder.vn/vi/tim-viec-lam/lap-trinh-vien-net.35AEC410.html" target="_blank">Lập Trình Viên .Net</a> <em class="set_jobnew">(Mới)</em></h3>,
#  <h3 class="job"><a href="https://careerbuilder.vn/vi/tim-viec-lam/chuong-trinh-tuyen-dung-20-lap-trinh-vien-fresher.35AE8425.html" target="_blank">Chương trình tuyển dụng 20 Lập trình viên Fresher</a> </h3>,
#  <h3 class="job"><a href="https://careerbuilder.vn/vi/tim-viec-lam/strategy-officer-vpbank.35AE0F26.html" target="_blank">Strategy Officer - VPBank</a> </h3>,
#  <h3 class="job"><a href="https://careerbuilder.vn/vi/tim-viec-lam/senior-developper-chuyen-gia-lap-trinh.35AE6B6C.html" target="_blank">Senior Developper - Chuyên Gia Lập Trình</a> </h3>,
#  <h3 class="job"><a href="https://careerbuilder.vn/vi/tim-viec-lam/tuyen-dung-tap-trung-can-bo-cong-nghe-thong-tin.35AE9F5A.html" target="_blank">Tuyển Dụng Tập Trung Cán Bộ Công Nghệ Thông Tin</a> </h3>,
# ...

# %%
len(tag_h3)
# Out:
# 50

# %%
job_title
# Out:
# ['Lập Trình Viên .Net (Mới)',
#  'Chương trình tuyển dụng 20 Lập trình viên Fresher ',
#  'Strategy Officer - VPBank ',
#  'Senior Developper - Chuyên Gia Lập Trình ',
#  'Tuyển Dụng Tập Trung Cán Bộ Công Nghệ Thông Tin ',
#  'PHP Developer (Mới)',
#  'PHP Developer (Mới)',
#  '[Ha Noi] Sales Representative (Mới)',
#  '[Hà Nội] Nhân Viên IT Helpdesk (Mới)',
#  'THỰC TẬP SINH PHP (Mới)',
#  'HO - Khối CNTT - Chuyên Viên Ban Quản Lý Dự Án (Mới)',
#  'HO - Khối CNTT - Chuyên Viên Phân Tích Nghiệp Vụ (BA) (Mới)',
#  'HO - Khối CNTT - Chuyên Viên Phát Triển Ứng Dụng Thanh Toán & Tích Hợp (Mới)',
#  'Penetration Testing ',
#  'Chuyên Viên Phát Triển Hệ Thống Đào Tạo E - Learning ',
#  'Chuyên viên IT quản trị hệ thống (Gấp) ',
#  'Chuyên Viên Phân Tích Malware ',
#  'Chuyên Gia Tư Vấn Giải Pháp ',
#  'Chuyên viên vận hành hệ thống Core chứng khoán ',
#  'Thực Tập Sinh/CTV Lập Trình Phần Mềm ',
#  'HO - Khối CNTT - Chuyên viên Phát triển ứng dụng Quản lý doanh nghiệp ',
# ...

# %%
job_title
# Out:
# ['Lập Trình Viên .Net',
#  'Chương trình tuyển dụng 20 Lập trình viên Fresher',
#  'Strategy Officer - VPBank',
#  'Senior Developper - Chuyên Gia Lập Trình',
#  'Tuyển Dụng Tập Trung Cán Bộ Công Nghệ Thông Tin',
#  'PHP Developer',
#  'PHP Developer',
#  '[Ha Noi] Sales Representative',
#  '[Hà Nội] Nhân Viên IT Helpdesk',
#  'THỰC TẬP SINH PHP',
#  'HO - Khối CNTT - Chuyên Viên Ban Quản Lý Dự Án',
#  'HO - Khối CNTT - Chuyên Viên Phân Tích Nghiệp Vụ (BA)',
#  'HO - Khối CNTT - Chuyên Viên Phát Triển Ứng Dụng Thanh Toán & Tích Hợp',
#  'Penetration Testing',
#  'Chuyên Viên Phát Triển Hệ Thống Đào Tạo E - Learning',
#  'Chuyên viên IT quản trị hệ thống (Gấp)',
#  'Chuyên Viên Phân Tích Malware',
#  'Chuyên Gia Tư Vấn Giải Pháp',
#  'Chuyên viên vận hành hệ thống Core chứng khoán',
#  'Thực Tập Sinh/CTV Lập Trình Phần Mềm',
#  'HO - Khối CNTT - Chuyên viên Phát triển ứng dụng Quản lý doanh nghiệp',
#  'Senior ERP Consultant',
#  'Software Engineer (Hà Nội)',
#  'Android Hacker',
# ...

# %%
job_links
# Out:
# ['https://careerbuilder.vn/vi/tim-viec-lam/lap-trinh-vien-net.35AEC410.html',
#  'https://careerbuilder.vn/vi/tim-viec-lam/chuong-trinh-tuyen-dung-20-lap-trinh-vien-fresher.35AE8425.html',
#  'https://careerbuilder.vn/vi/tim-viec-lam/strategy-officer-vpbank.35AE0F26.html',
#  'https://careerbuilder.vn/vi/tim-viec-lam/senior-developper-chuyen-gia-lap-trinh.35AE6B6C.html',
#  'https://careerbuilder.vn/vi/tim-viec-lam/tuyen-dung-tap-trung-can-bo-cong-nghe-thong-tin.35AE9F5A.html',
#  'https://careerbuilder.vn/vi/tim-viec-lam/ha-noi-nhan-vien-it-helpdesk.35AE940F.html',
#  'https://careerbuilder.vn/vi/tim-viec-lam/thuc-tap-sinh-php.35AEC68C.html',
#  'https://careerbuilder.vn/vi/tim-viec-lam/ho-khoi-cntt-chuyen-vien-ban-quan-ly-du-an.35AEC670.html',
#  'https://careerbuilder.vn/vi/tim-viec-lam/ho-khoi-cntt-chuyen-vien-ban-quan-ly-du-an.35AEC66F.html',
#  'https://careerbuilder.vn/vi/tim-viec-lam/ho-khoi-cntt-chuyen-vien-phan-tich-nghiep-vu-ba.35AEC66D.html',
# ...

# %%
type(job_location)
# Out:
# bs4.element.ResultSet

# %%
job_locations = [job_location[i].text for i in range(0, len(job_location))]

# %%
tag_p = soup.find_all('p', {'class': 'namecom'})

# %%
tag_p
# Out:
# [<p class="namecom"><a href="https://careerbuilder.vn/vi/nha-tuyen-dung/cong-ty-co-phan-tu-van-quan-tri-doanh-nghiep-tinh-van.35A7A44C.html">Công Ty Cổ Phần Tư vấn Quản Trị Doanh Nghiệp Tinh Vân</a></p>,
#  <p class="namecom"><a href="https://careerbuilder.vn/vi/nha-tuyen-dung/to-hop-cong-nghe-giao-duc-topica.35A6590E.html">Tổ Hợp Công Nghệ Giáo Dục Topica</a></p>,
#  <p class="namecom"><a href="https://careerbuilder.vn/vi/nha-tuyen-dung/ngan-hang-tmcp-viet-nam-thinh-vuong-vpbank.35A6CA10.html">Ngân Hàng TMCP Việt Nam Thịnh Vượng - VPBANK</a></p>,
#  <p class="namecom"><a href="https://careerbuilder.vn/vi/nha-tuyen-dung/to-hop-cong-nghe-giao-duc-topica.35A6590E.html">Tổ Hợp Công Nghệ Giáo Dục Topica</a></p>,
#  <p class="namecom"><a href="https://careerbuilder.vn/vi/nha-tuyen-dung/ngan-hang-tmcp-dau-tu-va-phat-trien-viet-nam.35A7DEFE.html">Ngân Hàng TMCP Đầu Tư và Phát Triển Việt Nam</a></p>,
# ...

# %%
len(tag_p)
# Out:
# 50

# %%
type(tag_p)
# Out:
# bs4.element.ResultSet

# %%
tag_p[0].text
# Out:
# 'Công Ty Cổ Phần Tư vấn Quản Trị Doanh Nghiệp Tinh Vân'

# %%
tag_p
# Out:
# [<p class="namecom"><a href="https://careerbuilder.vn/vi/nha-tuyen-dung/cong-ty-co-phan-tu-van-quan-tri-doanh-nghiep-tinh-van.35A7A44C.html">Công Ty Cổ Phần Tư vấn Quản Trị Doanh Nghiệp Tinh Vân</a></p>,
#  <p class="namecom"><a href="https://careerbuilder.vn/vi/nha-tuyen-dung/to-hop-cong-nghe-giao-duc-topica.35A6590E.html">Tổ Hợp Công Nghệ Giáo Dục Topica</a></p>,
#  <p class="namecom"><a href="https://careerbuilder.vn/vi/nha-tuyen-dung/ngan-hang-tmcp-viet-nam-thinh-vuong-vpbank.35A6CA10.html">Ngân Hàng TMCP Việt Nam Thịnh Vượng - VPBANK</a></p>,
#  <p class="namecom"><a href="https://careerbuilder.vn/vi/nha-tuyen-dung/to-hop-cong-nghe-giao-duc-topica.35A6590E.html">Tổ Hợp Công Nghệ Giáo Dục Topica</a></p>,
#  <p class="namecom"><a href="https://careerbuilder.vn/vi/nha-tuyen-dung/ngan-hang-tmcp-dau-tu-va-phat-trien-viet-nam.35A7DEFE.html">Ngân Hàng TMCP Đầu Tư và Phát Triển Việt Nam</a></p>,
# ...

# %%
tag_p[0]
# Out:
# <p class="namecom"><a href="https://careerbuilder.vn/vi/nha-tuyen-dung/cong-ty-co-phan-tu-van-quan-tri-doanh-nghiep-tinh-van.35A7A44C.html">Công Ty Cổ Phần Tư vấn Quản Trị Doanh Nghiệp Tinh Vân</a></p>

# %%
tag_p[49].a.text
# Out:
# 'Công Ty Cổ phần Công nghệ Thành Công Á Châu - VietInterview'

# %%
[tag_p[i].text for i in range(0, len(tag_p))]
# Out:
# ['Công Ty Cổ Phần Tư vấn Quản Trị Doanh Nghiệp Tinh Vân',
#  'Tổ Hợp Công Nghệ Giáo Dục Topica',
#  'Ngân Hàng TMCP Việt Nam Thịnh Vượng - VPBANK',
#  'Tổ Hợp Công Nghệ Giáo Dục Topica',
#  'Ngân Hàng TMCP Đầu Tư và Phát Triển Việt Nam',
#  'Công Ty TNHH FPT Trading',
#  'Tập đoàn Internet Novaon',
#  'LienVietPostBank',
#  'LienVietPostBank',
#  'LienVietPostBank',
#  'LienVietPostBank',
#  'Công ty cổ phần An ninh an toàn thông tin CMC',
#  'Công ty Cổ Phần Viễn Thông FPT',
#  'Công Ty Cổ Phần Quốc Tế Sơn Hà',
#  'Công ty cổ phần An ninh an toàn thông tin CMC',
#  'Công ty cổ phần An ninh an toàn thông tin CMC',
#  'Công Ty CP Chứng Khoán VNDIRECT',
#  'Công ty CP Đầu Tư Hàng Tiêu Dùng Quốc Tế',
#  'LienVietPostBank',
#  'CÔNG TY TNHH GLOBE 3 ERP VIỆT NAM',
#  'CÔNG TY TNHH GLOBE 3 ERP VIỆT NAM',
#  'Công Ty Cổ phần Công nghệ Thành Công Á Châu - VietInterview',
#  'Công Ty Cổ phần Công nghệ Thành Công Á Châu - VietInterview',
# ...

# %%
for i in range(0, len(tag_p)):
    tag_a = tag_p[i].a
    print(tag_a)
# Out:
# <a href="https://careerbuilder.vn/vi/nha-tuyen-dung/cong-ty-co-phan-tu-van-quan-tri-doanh-nghiep-tinh-van.35A7A44C.html">Công Ty Cổ Phần Tư vấn Quản Trị Doanh Nghiệp Tinh Vân</a>
# <a href="https://careerbuilder.vn/vi/nha-tuyen-dung/to-hop-cong-nghe-giao-duc-topica.35A6590E.html">Tổ Hợp Công Nghệ Giáo Dục Topica</a>
# <a href="https://careerbuilder.vn/vi/nha-tuyen-dung/ngan-hang-tmcp-viet-nam-thinh-vuong-vpbank.35A6CA10.html">Ngân Hàng TMCP Việt Nam Thịnh Vượng - VPBANK</a>
# <a href="https://careerbuilder.vn/vi/nha-tuyen-dung/to-hop-cong-nghe-giao-duc-topica.35A6590E.html">Tổ Hợp Công Nghệ Giáo Dục Topica</a>
# <a href="https://careerbuilder.vn/vi/nha-tuyen-dung/ngan-hang-tmcp-dau-tu-va-phat-trien-viet-nam.35A7DEFE.html">Ngân Hàng TMCP Đầu Tư và Phát Triển Việt Nam</a>
# <a href="https://careerbuilder.vn/vi/nha-tuyen-dung/cong-ty-tnhh-fpt-trading.35A7CACE.html">Công Ty TNHH FPT Trading</a>
# ...

# %%
job_company = [tag_p[i].a for i in range(0, len(tag_p))]
for i in range(0, len(job_company)):
    tag_a = job_company[i].get_text(strip = True)
    print(tag_a)
# Out:
# Công Ty Cổ Phần Tư vấn Quản Trị Doanh Nghiệp Tinh Vân
# Tổ Hợp Công Nghệ Giáo Dục Topica
# Ngân Hàng TMCP Việt Nam Thịnh Vượng - VPBANK
# Tổ Hợp Công Nghệ Giáo Dục Topica
# Ngân Hàng TMCP Đầu Tư và Phát Triển Việt Nam
# Công Ty TNHH FPT Trading
# Tập đoàn Internet Novaon
# LienVietPostBank
# LienVietPostBank
# LienVietPostBank
# LienVietPostBank
# Công ty cổ phần An ninh an toàn thông tin CMC
# Công ty Cổ Phần Viễn Thông FPT
# Công Ty Cổ Phần Quốc Tế Sơn Hà
# Công ty cổ phần An ninh an toàn thông tin CMC
# Công ty cổ phần An ninh an toàn thông tin CMC
# Công Ty CP Chứng Khoán VNDIRECT
# Công ty CP Đầu Tư Hàng Tiêu Dùng Quốc Tế
# LienVietPostBank
# CÔNG TY TNHH GLOBE 3 ERP VIỆT NAM
# CÔNG TY TNHH GLOBE 3 ERP VIỆT NAM
# Công Ty Cổ phần Công nghệ Thành Công Á Châu - VietInterview
# Công Ty Cổ phần Công nghệ Thành Công Á Châu - VietInterview
# Công Ty Cổ phần Công nghệ Thành Công Á Châu - VietInterview
# Công Ty TNHH MTV Wacontre
# ...

# %%
job_company[0].string
# Out:
# 'Công Ty Cổ Phần Tư vấn Quản Trị Doanh Nghiệp Tinh Vân'

# %%
tag_h3[0]
# Out:
# <h3 class="job"><a href="https://careerbuilder.vn/vi/tim-viec-lam/strategy-officer-vpbank.35AE0F26.html" target="_blank">Strategy Officer - VPBank</a> </h3>

# %%
len(tag_h3)
# Out:
# 50

# %%
tag_a = []

# %%
job_links
# Out:
# ['https://careerbuilder.vn/vi/tim-viec-lam/strategy-officer-vpbank.35AE0F26.html',
#  'https://careerbuilder.vn/vi/tim-viec-lam/senior-developper-chuyen-gia-lap-trinh.35AE6B6C.html',
#  'https://careerbuilder.vn/vi/tim-viec-lam/chuyen-vien-lap-trinh-java-full-stack.35AEA4F6.html',
#  'https://careerbuilder.vn/vi/tim-viec-lam/tuyen-dung-tap-trung-can-bo-cong-nghe-thong-tin.35AE9F5A.html',
#  'https://careerbuilder.vn/vi/tim-viec-lam/digital-marketing-executive-cvcc-marketing-khoi-dvnh-cong-nghe-so.35AE08C7.html',
#  'https://careerbuilder.vn/vi/tim-viec-lam/chuyen-vien-quan-tri-csdl-va-he-thong.35AEBDB8.html',
#  'https://careerbuilder.vn/vi/tim-viec-lam/nhan-vien-trien-khai-phan-mem.35AEBD75.html',
#  'https://careerbuilder.vn/vi/tim-viec-lam/nhan-vien-kinh-doanh-giai-phap-phan-mem.35AEBD74.html',
#  'https://careerbuilder.vn/vi/tim-viec-lam/nhan-vien-trien-khai-phan-mem.35AE1097.html',
# ...

# %%
len(job_links)
# Out:
# 50

# %%
job_location
# Out:
# [<p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội, Hồ Chí Minh, Toàn quốc</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hồ Chí Minh, Hà Nội</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội, Hồ Chí Minh</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hải Phòng, Hà Nội, Hải Dương</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội</p>,
# ...

# %%
len(job_location)
# Out:
# 50

# %%
# Out:
# ['Lương: 11 Tr - 33 Tr VND',
#  'Lương: 2 Tr - 4 Tr VND',
#  'Lương: 10 Tr - 30 Tr VND',
#  'Lương: 12 Tr - 18 Tr VND',
#  'Lương: 10 Tr - 20 Tr VND',
#  'Lương: 1 Tr - 2 Tr VND',
#  'Lương: 10 Tr - 12 Tr VND',
#  'Lương: 3 Tr - 5 Tr VND',
#  'Lương: 13,2 Tr - 33 Tr VND',
#  'Lương: 30 Tr - 60 Tr VND',
#  'Lương: 13,2 Tr - 33 Tr VND',
#  'Lương: 22 Tr - 33 Tr VND',
#  'Lương: 44 Tr - 88 Tr VND',
#  'Lương: 15,4 Tr - 22 Tr VND',
#  'Lương: 33 Tr - 44 Tr VND',
#  'Lương: 22 Tr - 55 Tr VND',
#  'Lương: 13,2 Tr - 33 Tr VND',
#  'Lương: 13,2 Tr - 33 Tr VND',
#  'Lương: Dưới 33 Tr VND',
#  'Lương: 8 Tr - 12 Tr VND',
#  'Lương: 22 Tr - 66 Tr VND',
#  'Lương: 22 Tr - 33 Tr VND',
#  'Lương: 7 Tr - 10 Tr VND',
#  'Lương: 17,6 Tr - 26,4 Tr VND',
#  'Lương: 16,5 Tr - 27,5 Tr VND',
#  'Lương: 22 Tr - 33 Tr VND',
#  'Lương: 19,8 Tr - 24,2 Tr VND',
#  'Lương: 17,6 Tr - 33 Tr VND',
#  'Lương: 30 Tr - 60 Tr VND',
#  'Lương: 22 Tr - 44 Tr VND',
#  'Lương: 12 Tr - 30 Tr VND',
# ...

# %%
data.head(50)
# Out:
#                                               company  \
# 0        Ngân Hàng TMCP Việt Nam Thịnh Vượng - VPBANK
# 1                    Tổ Hợp Công Nghệ Giáo Dục Topica
# 2                    Công Ty Cổ Phần Truyền Thông VMG
# 3        Ngân Hàng TMCP Đầu Tư và Phát Triển Việt Nam
# 4        Ngân Hàng TMCP Việt Nam Thịnh Vượng - VPBANK
# 5                                 CÔNG TY TNHH VENESA
# 6   CÔNG TY CỔ PHẦN PHẦN MỀM QUẢN TRỊ DOANH NGHIỆP...
# 7   CÔNG TY CỔ PHẦN PHẦN MỀM QUẢN TRỊ DOANH NGHIỆP...
# 8                      Công Ty Cổ Phần Phần Mềm Bravo
# 9         Công ty TNHH Sản xuất và Kinh doanh VinFast
# 10                     Tập Đoàn Vingroup - Công Ty CP
# 11                     Công Ty Cổ Phần Phần Mềm Bravo
# 12                          Công Ty TNHH MTV Wacontre
# 13           Công ty CP Đầu Tư Hàng Tiêu Dùng Quốc Tế
# 14        Công ty TNHH Sản xuất và Kinh doanh VinFast
# 15           Công ty CP Đầu Tư Hàng Tiêu Dùng Quốc Tế
# ...

# %%
sns.countplot(y = job_locations, data = data)

# %%
for i in range(0, len(job_location)):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
job_location
# Out:
# [<p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội, Hồ Chí Minh, Toàn quốc</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hồ Chí Minh, Hà Nội</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội, Hồ Chí Minh</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hải Phòng, Hà Nội, Hải Dương</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội</p>,
# ...

# %%
job_location
# Out:
# [<p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội, Hồ Chí Minh, Toàn quốc</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hồ Chí Minh, Hà Nội</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội, Hồ Chí Minh</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hải Phòng, Hà Nội, Hải Dương</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội</p>,
#  <p class="location"><i class="fa fa-map-marker fa-fw"></i>Hà Nội</p>,
# ...

# %%
tag_h3.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-2bf74682c2a2> in <module>()
# ----> 1 tag_h3.text
#
# ~/api/api/lib/python3.5/site-packages/bs4/element.py in __getattr__(self, key)
#    1805     def __getattr__(self, key):
#    1806         raise AttributeError(
# -> 1807             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1808         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
for i in tag_h3:
    tag_h3_a = tag_h3.find_all('a')
print(tag_h3_a)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-33d07d469546> in <module>()
#       1 for i in tag_h3:
# ----> 2     tag_h3_a = tag_h3.find_all('a')
#       3 print(tag_h3_a)
#
# ~/api/api/lib/python3.5/site-packages/bs4/element.py in __getattr__(self, key)
#    1805     def __getattr__(self, key):
#    1806         raise AttributeError(
# -> 1807             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1808         )
#
# AttributeError: ResultSet object has no attribute 'find_all'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
soup.h3.find_all('a')
# Out:
# []

# %%
# Out:
# <div class="col-xs-6"><a class="btn" href="https://careerbuilder.vn/vi/jobseekers/login">Đăng nhập</a></div>

# %%
tag_a
# Out:
# <a class="btn" href="https://careerbuilder.vn/vi/jobseekers/login">Đăng nhập</a>

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="vi">
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="nofollow" name="googlebot"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <title>Tìm việc làm CNTT - Phần mềm tại Hà Nội | CareerBuilder.vn</title>
# <meta content="Việc làm, kiếm việc, tìm việc làm, tuyển dụng, ứng viên,  mạng tuyển dụng, việc làm online, HR, nghành nghề hot, công ty hàng đầu Việt Nam, việc làm bán thời gian" name="keywords">
# <meta content="Có 682 việc làm CNTT - Phần mềm tại Hà Nội từ nhà tuyển dụng hàng đầu đang được đăng tuyển. Tìm việc và ứng tuyển ngay hôm nay!" name="description"/>
# <link href="https://careerbuilder.vn/viec-lam/cntt-phan-mem-tai-ha-noi-c1l4-vi.html" hreflang="vi" rel="alternate"/>
# <link href="https://careerbuilder.vn/jobs/it-software-in-ha-noi-c1l4-en.html" hreflang="en" rel="alternate"/>
# ...
